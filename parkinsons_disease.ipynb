# %% [markdown]
# <a href="https://colab.research.google.com/github/Fahimunnisha/Align-guard-intern/blob/main/parkinsons_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PARKINSON'S DISEASE**
# WHAT IS PARKINSON'S DISEASE?
# Parkinson's disease is a progressive disorder that affects the nervous system and the parts of the body controlled by the nerves. Symptoms start slowly. The first symptom may be a barely noticeable tremor in just one hand. Tremors are common, but the disorder also may cause stiffness or slowing of movement.
#
# In the early stages of Parkinson's disease, your face may show little or no expression. Your arms may not swing when you walk. Your speech may become soft or slurred. Parkinson's disease symptoms worsen as your condition progresses over time.
# **DESCRIPTION:**
# name - ASCII subject name and recording number
# MDVP:Fo(Hz) - Average vocal fundamental frequency
# MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
# MDVP:Flo(Hz) - Minimum vocal fundamental frequency
# MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several
# measures of variation in fundamental frequency
# MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
# NHR,HNR - Two measures of ratio of noise to tonal components in the voice
# status - Health status of the subject (one) - Parkinson's, (zero) - healthy
# RPDE,D2 - Two nonlinear dynamical complexity measures
# DFA - Signal fractal scaling exponent
# spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
disease=pd.read_csv("/content/parkinsons data.csv")

# %%
disease.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
disease.shape
# Out:
# (195, 24)

# %%
disease.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
disease.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
disease.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
disease=disease.drop(columns=['name'])

# %%
df = pd.DataFrame(disease)

# Calculating the range and variance for each feature
ranges = df.max() - df.min()
variances = df.var()

# Plotting the range for each feature
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
ranges.plot(kind='bar', color='skyblue')
plt.title('Range of Each Feature')
plt.ylabel('Range')
plt.xlabel('Feature')

# Plotting the variance for each feature
plt.subplot(1, 2, 2)
variances.plot(kind='bar', color='salmon')
plt.title('Variance of Each Feature')
plt.ylabel('Variance')
plt.xlabel('Feature')

plt.tight_layout()
plt.show()

# %%
disease.shape
# Out:
# (195, 23)

# %%
null_values=disease.isna().sum()
print(null_values)
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
print(disease.duplicated().sum())
# Out:
# 0

# %%
data_type=disease.dtypes
print(data_type)
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
missing_values = disease.isnull().sum()
print(missing_values)
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
plt.boxplot(disease['MDVP:Fhi(Hz)'])
plt.title('Boxplot for column1')
plt.show()

# %%
plt.boxplot(disease['Shimmer:APQ5'])
plt.title('Boxplot for column2')
plt.show()

# %%
plt.boxplot(disease['HNR'])
plt.title('Boxplot for column3')
plt.show()

# %%
plt.boxplot(disease['RPDE'])
plt.title('Boxplot for column4')
plt.show()

# %%
plt.boxplot(disease['status'])
plt.title('Boxplot for column1')
plt.show()

# %%
plt.boxplot(disease['spread1'])
plt.title('Boxplot for column6')
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
sns.boxplot(disease, x = 'MDVP:Fo(Hz)', ax = ax1, color = 'r')
sns.boxplot(disease, x = 'MDVP:Fhi(Hz)', ax = ax2, color = 'b')
sns.boxplot(disease, x = 'MDVP:Flo(Hz)', ax = ax3, color = 'g')
sns.boxplot(disease, x = 'MDVP:Shimmer(dB)', ax = ax4, color = 'm')
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
sns.boxplot(disease, x = 'NHR', ax = ax1, color = 'orange')
sns.boxplot(disease, x = 'HNR', ax = ax2, color = 'cyan')
sns.boxplot(disease, x = 'RPDE', ax = ax3, color = 'brown')
sns.boxplot(disease, x = 'DFA', ax = ax4, color = 'yellow')
plt.show()

# %%
disease.hist(figsize=(15,15));

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


df = pd.DataFrame(disease)

# Visualize data before removing outliers using box plots
plt.figure(figsize=(5,5))
plt.suptitle('Box Plots Before Removing Outliers', fontsize=16)

for i, col in enumerate(['MDVP:Fhi(Hz)','MDVP:Fhi(Hz)','MDVP:Flo(Hz)','MDVP:Shimmer(dB)']):


    plt.subplot(2, 2, i+1)
    sns.boxplot(y=df[col])
    plt.title(f'{col}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Detect and remove outliers using Z-score
def remove_outliers(disease):

    Q1 = disease.quantile(0.25)
    Q3 = disease.quantile(0.75)
    IQR = Q3 - Q1


    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR


    df_no_outliers = disease[~((disease < lower_bound) | (disease > upper_bound)).any(axis=1)]
    return df_no_outliers

# Call the function to remove outliers and create df_no_outliers
df_no_outliers = remove_outliers(disease) # Call the function here

# Visualize data after removing outliers using box plots
plt.figure(figsize=(5,5))
plt.suptitle('Box Plots After Removing Outliers', fontsize=16)

for i, col in enumerate(['MDVP:Fhi(Hz)','MDVP:Fhi(Hz)','MDVP:Flo(Hz)','MDVP:Shimmer(dB)']):
    plt.subplot(2, 2, i+1)
    sns.boxplot(y=df_no_outliers[col])
    plt.title(f'{col}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# Z-SCORE
# z = ( x - μ ) / σ
# WHERE,
# z = Z-score
# x = the value being evaluated
# μ = the mean
# σ = the standard deviation
#
# x = 57
# μ = 52
# σ = 4
# You would use the variables in the formula:
#
# z = ( 57 - 52 ) / 4
# z = 1.25
# So, your selected value has a z-score that indicates it is 1.25 standard deviations from the mean.

# %%
from scipy import stats

z_scores = stats.zscore(disease.select_dtypes(include=[float, int]))
abs_z_scores = np.abs(z_scores)
outliers = (abs_z_scores > 3).all(axis=1)
print(disease[outliers])
disease = disease[~outliers]
print("Data without outliers (Z-score):")
print(outliers)
# Out:
# Empty DataFrame
# Columns: [MDVP:Fo(Hz), MDVP:Fhi(Hz), MDVP:Flo(Hz), MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, MDVP:APQ, Shimmer:DDA, NHR, HNR, status, RPDE, DFA, spread1, spread2, D2, PPE]
# Index: []
#
# [0 rows x 23 columns]
# Data without outliers (Z-score):
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


df = pd.DataFrame(disease)

# Visualize data before removing outliers using box plots
plt.figure(figsize=(5,5))
plt.suptitle('Box Plots Before Removing Outliers', fontsize=16)

for i, col in enumerate(['MDVP:Fhi(Hz)','MDVP:Fhi(Hz)','MDVP:Flo(Hz)','MDVP:Shimmer(dB)']):


    plt.subplot(2, 2, i+1)
    sns.boxplot(y=df[col])
    plt.title(f'{col}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Detect and remove outliers using Z-score
def remove_outliers(disease):

    Q1 = disease.quantile(0.25)
    Q3 = disease.quantile(0.75)
    IQR = Q3 - Q1


    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR


    df_no_outliers = disease[~((disease < lower_bound) | (disease > upper_bound)).any(axis=1)]
    return df_no_outliers

# Call the function to remove outliers and create df_no_outliers
df_no_outliers = remove_outliers(disease) # Call the function here

# Visualize data after removing outliers using box plots
plt.figure(figsize=(5,5))
plt.suptitle('Box Plots After Removing Outliers', fontsize=16)

for i, col in enumerate(['MDVP:Fhi(Hz)','MDVP:Fhi(Hz)','MDVP:Flo(Hz)','MDVP:Shimmer(dB)']):
    plt.subplot(2, 2, i+1)
    sns.boxplot(y=df_no_outliers[col])
    plt.title(f'{col}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
sns.boxplot(disease, x = 'MDVP:Fo(Hz)', ax = ax1, color = 'r')
sns.boxplot(disease, x = 'MDVP:Fhi(Hz)', ax = ax2, color = 'b')
sns.boxplot(disease, x = 'MDVP:Flo(Hz)', ax = ax3, color = 'g')
sns.boxplot(disease, x = 'MDVP:Shimmer(dB)', ax = ax4, color = 'm')
plt.show()

# %%
z_scores = stats.zscore(disease)

# %%
print(z_scores)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0      -0.829300     -0.436165     -0.952037        0.334914
# 1      -0.770972     -0.530974     -0.057721        0.715418
# 2      -0.909476     -0.723168     -0.109875        0.884991
# 3      -0.909622     -0.649092     -0.114229        0.775389
# 4      -0.925657     -0.606245     -0.130608        1.368893
# ..           ...           ...           ...             ...
# 190     0.483467      0.371185     -0.508265       -0.337173
# 191     1.339202      0.612690     -0.618218       -0.120037
# 192     0.495578      0.470104     -0.968393        1.526058
# 193     1.078761      2.190044     -0.954180        0.243924
# 194     1.454817      0.692246     -0.883481       -0.113833
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            0.749759  0.132963  0.760800    0.131755      0.745985
# 1            1.037674  0.453892  1.276809    0.452684      1.681731
# ...

# %%
def remove_outliers(disease):

    Q1 = disease.quantile(0.25)
    Q3 = disease.quantile(0.75)
    IQR = Q3 - Q1


    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR


    df_no_outliers = disease[~((disease < lower_bound) | (disease > upper_bound)).any(axis=1)]

    return df_no_outliers

# %%
data_no_outliers = remove_outliers(disease)

print("Original Data:")
print(disease)

print("\nData after removing outliers:")
print(data_no_outliers)
# Out:
# Original Data:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 8))
sns.boxplot(disease, x = 'MDVP:Fo(Hz)', ax = ax1, color = 'r')
sns.boxplot(disease, x = 'MDVP:Fhi(Hz)', ax = ax2, color = 'b')
sns.boxplot(disease, x = 'MDVP:Flo(Hz)', ax = ax3, color = 'g')
sns.boxplot(disease, x = 'MDVP:Shimmer(dB)', ax = ax4, color = 'm')
plt.show()

# %%
disease['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
sns.heatmap(disease.corr())
# Out:
# <Axes: >

# %%
x = disease.drop(columns=['status'])
y = disease['status']

# %%
from sklearn.ensemble import RandomForestRegressor



rf = RandomForestRegressor()
rf.fit(x, y)


importances = rf.feature_importances_
indices = np.argsort(importances)

plt.figure()
plt.title("Feature importances")
plt.barh(range(x.shape[1]), importances[indices], align='center')
plt.yticks(range(x.shape[1]), [x.columns[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
scaler = StandardScaler()
x_std = scaler.fit_transform(x)

# %%
x_std
# Out:
# array([[-0.82929965, -0.43616456, -0.95203729, ...,  0.48047686,
#         -0.21053082,  0.86888575],
#        [-0.77097169, -0.53097409, -0.05772056, ...,  1.31118546,
#          0.27507712,  1.80360503],
#        [-0.90947638, -0.7231683 , -0.10987483, ...,  1.01768236,
#         -0.10362861,  1.40266141],
#        ...,
#        [ 0.49557839,  0.47010361, -0.96839309, ..., -0.81807931,
#          0.78033848, -0.83241014],
#        [ 1.07876114,  2.19004398, -0.95417967, ..., -0.22906571,
#         -0.63700298, -0.92610456],
#        [ 1.45481664,  0.69224632, -0.88348115, ..., -0.43085284,
#          0.45480231, -0.64505466]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x_std,y,test_size = 0.2 , stratify=y , random_state=2)

# %%
x_train.shape , x_test.shape
# Out:
# ((156, 22), (39, 22))

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
pred_train = model.predict(x_train)
accuracy_score(pred_train,y_train)
# Out:
# 0.8910256410256411

# %%
pred_test = model.predict(x_test)
accuracy_score(pred_test,y_test)
# Out:
# 0.8974358974358975

# %%
input_data = (223.365,238.987,98.664,0.00264,0.00001,0.00154,0.00151,0.00461,0.01906,0.165,0.01013,0.01296,0.0134,0.03039,0.00301,26.138,0.447979,0.686264,-7.293801,0.086372,2.32156,0.098555)


input_data_array = np.asarray(input_data)


input_data_reshape = input_data_array.reshape(1,-1)


std_data = scaler.transform(input_data_reshape,)


prediction = model.predict(std_data)

print(prediction)
if prediction == 0:
    print("The Person does not have Parkinsson's Disease")
else:
    print("The Person is suffering from parkinsson's Disease")
# Out:
# [0]
# The Person does not have Parkinsson's Disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from scipy.stats import skew


skewness = skew(disease)
print(f"Skewness: {skewness}")
# Out:
# Skewness: [ 0.58717588  2.52254909  1.20796613  3.06116496  2.62865025  3.33480141
#   3.05019642  3.336141    1.65363384  1.98397574  1.56839203  1.78483126
#   2.5978645   1.56843332  4.18817251 -0.51035273 -1.17857143 -0.14229695
#  -0.03295762  0.42880766  0.1433171   0.42706615  0.79134337]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=skewness)
plt.title('Boxplot of the Dataset')
plt.xlabel('Dataset')


plt.show()

# %%
disease.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Fo(Hz)'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Fo(Hz)'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Fhi(Hz)'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Fo(Hz)'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Flo(Hz)'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Flo(Hz)'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Jitter(%)'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Jitter(%)'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Jitter(Abs)'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Jitter(Abs)'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
disease.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:RAP'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:RAP'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:PPQ'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:PPQ'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
disease.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['Jitter:DDP'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['Jitter:DDP'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Shimmer'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Shimmer'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:Shimmer(dB)'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:Shimmer(dB)'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['Shimmer:APQ3'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['Shimmer:APQ3'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['Shimmer:APQ5'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['Shimmer:APQ5'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['MDVP:APQ'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['MDVP:APQ'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
disease.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['Shimmer:DDA'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['Shimmer:DDA'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['NHR'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['NHR'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
from scipy.stats import boxcox
data=disease['HNR']
boxcox_data, fitted_lambda = boxcox(data)

# Visualize the transformation
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data, kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(boxcox_data, kde=True)
plt.title(f'Box-Cox Transformed Data (lambda={fitted_lambda:.2f})')

plt.tight_layout()
plt.show()

# %%
disease.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
from scipy.stats import skew


skewness = skew(disease)
print(f"Skewness: {skewness}")
# Out:
# Skewness: [ 0.58717588  2.52254909  1.20796613  3.06116496  2.62865025  3.33480141
#   3.05019642  3.336141    1.65363384  1.98397574  1.56839203  1.78483126
#   2.5978645   1.56843332  4.18817251 -0.51035273 -1.17857143 -0.14229695
#  -0.03295762  0.42880766  0.1433171   0.42706615  0.79134337]

# %%
from sklearn.preprocessing import PowerTransformer

data = disease['status'].values.reshape(-1, 1) # Reshape the data to 2D

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data)
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data.ravel(), kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(yj_data.ravel(), kde=True)
plt.title('Yeo-Johnson Transformed Data')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

data = disease['DFA'].values.reshape(-1, 1)

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data)
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data.ravel(), kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(yj_data.ravel(), kde=True)
plt.title('Yeo-Johnson Transformed Data')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

data = disease['RPDE'].values.reshape(-1, 1)

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data)
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data.ravel(), kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(yj_data.ravel(), kde=True)
plt.title('Yeo-Johnson Transformed Data')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

data = disease['spread1'].values.reshape(-1, 1)

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data)
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data.ravel(), kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(yj_data.ravel(), kde=True)
plt.title('Yeo-Johnson Transformed Data')

plt.tight_layout()
plt.show()

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['spread2'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['spread2'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

data = disease['D2'].values.reshape(-1, 1)

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data)
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data.ravel(), kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(yj_data.ravel(), kde=True)
plt.title('Yeo-Johnson Transformed Data')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

data = disease['PPE'].values.reshape(-1, 1)

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data)
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
sns.histplot(data.ravel(), kde=True)
plt.title('Original Data')

plt.subplot(2, 1, 2)
sns.histplot(yj_data.ravel(), kde=True)
plt.title('Yeo-Johnson Transformed Data')

plt.tight_layout()
plt.show()

# %%
data = disease['HNR'].values.reshape(-1, 1)
original_skewness = skew(data)
print(f"Skewness of Original Data: {original_skewness[0]:.4f}")

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data).flatten()


transformed_skewness = skew(yj_data)
print(f"Skewness of Yeo-Johnson Transformed Data: {transformed_skewness:.4f}")
# Out:
# Skewness of Original Data: -0.5104
# Skewness of Yeo-Johnson Transformed Data: 0.0039

# %%
data = disease['DFA'].values.reshape(-1, 1)
original_skewness = skew(data)
print(f"Skewness of Original Data: {original_skewness[0]:.4f}")

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data).flatten()


transformed_skewness = skew(yj_data)
print(f"Skewness of Yeo-Johnson Transformed Data: {transformed_skewness:.4f}")
# Out:
# Skewness of Original Data: -0.0330
# Skewness of Yeo-Johnson Transformed Data: -0.0103

# %%
data = disease['RPDE'].values.reshape(-1, 1)
original_skewness = skew(data)
print(f"Skewness of Original Data: {original_skewness[0]:.4f}")

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data).flatten()


transformed_skewness = skew(yj_data)
print(f"Skewness of Yeo-Johnson Transformed Data: {transformed_skewness:.4f}")
# Out:
# Skewness of Original Data: -0.1423
# Skewness of Yeo-Johnson Transformed Data: -0.0437

# %%
data = disease['spread1'].values.reshape(-1, 1)
original_skewness = skew(data)
print(f"Skewness of Original Data: {original_skewness[0]:.4f}")

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data).flatten()


transformed_skewness = skew(yj_data)
print(f"Skewness of Yeo-Johnson Transformed Data: {transformed_skewness:.4f}")
# Out:
# Skewness of Original Data: 0.4288
# Skewness of Yeo-Johnson Transformed Data: 0.0533

# %%
data = disease['PPE'].values.reshape(-1, 1)
original_skewness = skew(data)
print(f"Skewness of Original Data: {original_skewness[0]:.4f}")

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data).flatten()


transformed_skewness = skew(yj_data)
print(f"Skewness of Yeo-Johnson Transformed Data: {transformed_skewness:.4f}")
# Out:
# Skewness of Original Data: 0.7913
# Skewness of Yeo-Johnson Transformed Data: 0.0445

# %%
data = disease['DFA'].values.reshape(-1, 1)
original_skewness = skew(data)
print(f"Skewness of Original Data: {original_skewness[0]:.4f}")

pt = PowerTransformer(method='yeo-johnson')
yj_data = pt.fit_transform(data).flatten()


transformed_skewness = skew(yj_data)
print(f"Skewness of Yeo-Johnson Transformed Data: {transformed_skewness:.4f}")
# Out:
# Skewness of Original Data: -0.0330
# Skewness of Yeo-Johnson Transformed Data: -0.0103

# %%
if len(disease) > 10000:
    disease_sampled = disease.sample(10000)
else:
    disease_sampled = disease
log_data = np.log1p(disease_sampled['D2'])
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
sns.histplot(disease_sampled['D2'], kde=True)
plt.title('Original Data')
plt.subplot(2, 1, 2)
sns.histplot(log_data, kde=True)
plt.title('Log Transformed Data')

plt.tight_layout()
plt.show()

# %%
data = disease['MDVP:Fhi(Hz)']

original_skewness = skew(data)
print(f"Skewness of original data: {original_skewness}")


log_data = np.log1p(data)


log_skewness = skew(log_data)
print(f"Skewness of log-transformed data: {log_skewness}")
# Out:
# Skewness of original data: 2.5225490936388146
# Skewness of log-transformed data: 1.089171776165911

# %%
data=disease['MDVP:Fo(Hz)']
original_skewness = skew(data)
print(f"Skewness of original data: {original_skewness}")
log_data = np.log1p(data)
log_skewness = skew(log_data)
print(f"Skewness of log-transformed data: {log_skewness}")
# Out:
# Skewness of original data: 0.5871758758264713
# Skewness of log-transformed data: 0.214937144725993
